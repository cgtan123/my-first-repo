# %% [markdown]
# <a href="https://colab.research.google.com/github/cgtan123/my-first-repo/blob/main/TA02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.learn_model import LinearRegression
